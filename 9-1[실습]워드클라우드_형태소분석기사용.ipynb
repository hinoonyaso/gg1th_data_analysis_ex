# %% [markdown]
# # 한글 형태소 분석, Wordcloud 시각화
# - https://wikidocs.net/127851
# - 예제 : https://wikidocs.net/172882
#
# ### 설치 라이브러리
# - pip install wordcloud
# - pip install konlpy
#
# #### java 다운로드 설치하기(Konlpy 실행을 위해 필요함)
# https://www.oracle.com/java/technologies/javase/jdk23-archive-downloads.html
# - 다운로드 받아서 기본 설치
# - 시스템 환경변수에 JAVA_HOME 정의 및 path 설정 : %JAVA_HOME%/bin
#
# ### font 파일 다운로드
# - curl -L -O https://github.com/byungjooyoo/Dataset/raw/main/NanumGothic.ttf
# ### 이미지 다운로드
# - curl -L -O https://github.com/byungjooyoo/Dataset/raw/main/korea_map.png
# - curl -L -O https://raw.githubusercontent.com/byungjooyoo/Dataset/main/heart.png

# %% [markdown]
# ## 라이브러리 로딩

# %%
# uv add wordcloud konlpy

# %%
from wordcloud import WordCloud  # 워드 클라우드를 그리기
from konlpy.tag import Komoran   # 형태소 분석기, 품사 태깅
from konlpy.corpus import kolaw  # 법율문서 말뭉치
import matplotlib.pyplot as plt

# %% [markdown]
# ## 대상 텍스트(말뭉치) 다운로드
# - https://konlpy.org/ko/latest/index.html
# - https://konlpy.org/ko/latest/data/

# %%
# 파일이름 확인
kolaw.fileids()
# Out:
# ['constitution.txt']

# %%
# 말뭉치 파일 읽기, 우리나라 헌법 데이터
para = kolaw.open('constitution.txt').read()
print(type(para))
para[:500]
# Out:
# <class 'str'>
# '대한민국헌법\n\n유구한 역사와 전통에 빛나는 우리 대한국민은 3·1운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 4·19민주이념을 계승하고, 조국의 민주개혁과 평화적 통일의 사명에 입각하여 정의·인도와 동포애로써 민족의 단결을 공고히 하고, 모든 사회적 폐습과 불의를 타파하며, 자율과 조화를 바탕으로 자유민주적 기본질서를 더욱 확고히 하여 정치·경제·사회·문화의 모든 영역에 있어서 각인의 기회를 균등히 하고, 능력을 최고도로 발휘하게 하며, 자유와 권리에 따르는 책임과 의무를 완수하게 하여, 안으로는 국민생활의 균등한 향상을 기하고 밖으로는 항구적인 세계평화와 인류공영에 이바지함으로써 우리들과 우리들의 자손의 안전과 자유와 행복을 영원히 확보할 것을 다짐하면서 1948년 7월 12일에 제정되고 8차에 걸쳐 개정된 헌법을 이제 국회의 의결을 거쳐 국민투표에 의하여 개정한다.\n\n       제1장 총강\n  제1조 ① 대한민국은 민주공화국이다.\n②대한민국의 주권은 국민에게 있고, '

# %% [markdown]
# ## 형태소 분석
# - 형태소란? 언어학에서 일정한 의미를 가진 가장 작은 말의 단위를 말합니다. 다시 말해, 더 이상 쪼개면 의미가 없어지는 말의 조각

# %%
# 형태소 분석 -> 명사만 뽑기
tagger = Komoran()
# tagger.morphs(para) # 모든 형태소 추출
# tagger.pos(para)      # (형태소, 품사(태그)) 쌍 추출
# tagger.nouns(para)  # 명사만 추출
nouns = tagger.nouns(para)  # 명사만 추출
tagger.pos(para)
# Out:
# [('대한민국', 'NNP'),
#  ('헌법', 'NNP'),
#  ('유구', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('역사', 'NNG'),
#  ('와', 'JC'),
#  ('전통', 'NNG'),
#  ('에', 'JKB'),
#  ('빛나', 'VV'),
#  ('는', 'ETM'),
#  ('우리', 'NP'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('국민', 'NNP'),
#  ('은', 'JX'),
#  ('3', 'SN'),
#  ('·', 'SP'),
#  ('1', 'SN'),
#  ('운동', 'NNP'),
#  ('으로', 'JKB'),
#  ('건립', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('대한민국', 'NNP'),
#  ('임시', 'NNG'),
#  ('정부', 'NNG'),
#  ('의', 'JKG'),
#  ('법통', 'NNG'),
#  ('과', 'JC'),
#  ('불의', 'NNP'),
#  ('에', 'JKB'),
#  ('항거', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('4', 'SN'),
#  ('·', 'SP'),
#  ('19', 'SN'),
#  ('민주', 'NNP'),
#  ('이념', 'NNG'),
#  ('을', 'JKO'),
#  ('계승', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('조국', 'NNP'),
#  ('의', 'JKG'),
#  ('민주개혁', 'NNG'),
#  ('과', 'JC'),
#  ('평화', 'NNG'),
#  ('적', 'XSN'),
#  ('통일', 'NNG'),
#  ('의', 'JKG'),
#  ('사명', 'NNG'),
#  ('에', 'JKB'),
#  ('입각', 'NNG'),
#  ('하', 'XSV'),
#  ('아', 'EC'),
#  ('정의', 'NNG'),
#  ('·', 'SP'),
#  ('인도', 'NNP'),
#  ('와', 'JC'),
#  ('동포애', 'NNG'),
#  ('로써', 'JKB'),
#  ('민족', 'NNG'),
#  ('의', 'JKG'),
#  ('단결', 'NNG'),
#  ('을', 'JKO'),
#  ('공고히', 'MAG'),
#  ('하', 'VV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('모든', 'MM'),
#  ('사회', 'NNG'),
#  ('적', 'XSN'),
#  ('폐습', 'NNG'),
#  ('과', 'JC'),
#  ('불의', 'NNP'),
#  ('를', 'JKO'),
#  ('타파', 'NNG'),
#  ('하', 'XSV'),
#  ('며', 'EC'),
#  (',', 'SP'),
#  ('자율', 'NNG'),
#  ('과', 'JC'),
#  ('조화', 'NNG'),
#  ('를', 'JKO'),
#  ('바탕', 'NNG'),
#  ('으로', 'JKB'),
#  ('자유', 'NNG'),
#  ('민주', 'NNP'),
#  ('적', 'XSN'),
#  ('기본', 'NNG'),
#  ('질서', 'NNG'),
#  ('를', 'JKO'),
#  ('더욱', 'MAG'),
#  ('확고히', 'MAG'),
#  ('하', 'VV'),
#  ('아', 'EC'),
#  ('정치', 'NNG'),
#  ('·', 'SP'),
#  ('경제', 'NNP'),
#  ('·', 'SP'),
#  ('사회', 'NNP'),
#  ('·', 'SP'),
#  ('문화', 'NNP'),
#  ('의', 'JKG'),
#  ('모든', 'MM'),
#  ('영역', 'NNG'),
#  ('에', 'JKB'),
#  ('있', 'VV'),
#  ('어서', 'EC'),
#  ('각인', 'NNG'),
#  ('의', 'JKG'),
#  ('기회', 'NNG'),
#  ('를', 'JKO'),
#  ('균등히', 'NA'),
#  ('하', 'VV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('능력', 'NNG'),
#  ('을', 'JKO'),
#  ('최고', 'NNP'),
#  ('도로', 'NNP'),
#  ('발휘', 'NNG'),
#  ('하', 'XSV'),
#  ('게', 'EC'),
#  ('하', 'VV'),
#  ('며', 'EC'),
#  (',', 'SP'),
#  ('자유', 'NNG'),
#  ('와', 'JC'),
#  ('권리', 'NNG'),
#  ('에', 'JKB'),
#  ('따르', 'VV'),
#  ('는', 'ETM'),
#  ('책임', 'NNG'),
#  ('과', 'JC'),
#  ('의무', 'NNG'),
#  ('를', 'JKO'),
#  ('완수', 'NNG'),
#  ('하', 'XSV'),
#  ('게', 'EC'),
#  ('하', 'VV'),
#  ('아', 'EC'),
#  (',', 'SP'),
#  ('안', 'NNG'),
#  ('으로', 'JKB'),
#  ('는', 'JX'),
#  ('국민', 'NNG'),
#  ('생활', 'NNG'),
#  ('의', 'JKG'),
#  ('균등', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('향상', 'NNG'),
#  ('을', 'JKO'),
#  ('기하', 'VV'),
#  ('고', 'EC'),
#  ('밖', 'NNG'),
#  ('으로', 'JKB'),
#  ('는', 'JX'),
#  ('항구', 'NNG'),
#  ('적', 'XSN'),
#  ('이', 'VCP'),
#  ('ㄴ', 'ETM'),
#  ('세계', 'NNG'),
#  ('평화', 'NNP'),
#  ('와', 'JC'),
#  ('인류', 'NNG'),
#  ('공영', 'NNG'),
#  ('에', 'JKB'),
#  ('이바지', 'NNG'),
#  ('하', 'XSV'),
#  ('ㅁ', 'ETN'),
#  ('으로써', 'JKB'),
#  ('우리', 'NP'),
#  ('들', 'XSN'),
#  ('과', 'JC'),
#  ('우리들의', 'NNP'),
#  ('자손', 'NNG'),
#  ('의', 'JKG'),
#  ('안전', 'NNG'),
#  ('과', 'JC'),
#  ('자유', 'NNG'),
#  ('와', 'JC'),
#  ('행복', 'NNG'),
#  ('을', 'JKO'),
#  ('영원히', 'MAG'),
#  ('확보', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('것', 'NNB'),
#  ('을', 'JKO'),
#  ('다짐', 'NNG'),
#  ('하', 'XSV'),
#  ('면서', 'EC'),
#  ('1948', 'SN'),
#  ('년', 'NNB'),
#  ('7월 12일', 'NNP'),
#  ('에', 'JKB'),
#  ('제정', 'NNG'),
#  ('되', 'XSV'),
#  ('고', 'EC'),
#  ('8', 'SN'),
#  ('차', 'NNB'),
#  ('에', 'JKB'),
#  ('걸치', 'VV'),
#  ('어', 'EC'),
#  ('개정', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('헌법', 'NNG'),
#  ('을', 'JKO'),
#  ('이제', 'MAG'),
#  ('국회', 'NNG'),
#  ('의', 'JKG'),
#  ('의결', 'NNG'),
#  ('을', 'JKO'),
#  ('거치', 'VV'),
#  ('어', 'EC'),
#  ('국민', 'NNG'),
#  ('투표', 'NNP'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('개정', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('1', 'SN'),
#  ('장', 'NNP'),
#  ('총', 'MM'),
#  ('강', 'NNP'),
#  ('제', 'XPN'),
#  ('1', 'SN'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('대한민국', 'NNP'),
#  ('은', 'JX'),
#  ('민주공화국', 'NNP'),
#  ('이', 'VCP'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('대한민국', 'NNP'),
#  ('의', 'JKG'),
#  ('주권', 'NNP'),
#  ('은', 'JX'),
#  ('국민', 'NNG'),
#  ('에게', 'JKB'),
#  ('있', 'VV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('모든', 'MM'),
#  ('권력', 'NNG'),
#  ('은', 'JX'),
#  ('국민', 'NNG'),
#  ('으로부터', 'JKB'),
#  ('나오', 'VV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('2', 'SN'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('대한민국', 'NNP'),
#  ('의', 'JKG'),
#  ('국민', 'NNG'),
#  ('이', 'JKS'),
#  ('되', 'VV'),
#  ('는', 'ETM'),
#  ('요건', 'NNG'),
#  ('은', 'JX'),
#  ('법률', 'NNG'),
#  ('로', 'JKB'),
#  ('정하', 'VV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('국가', 'NNP'),
#  ('는', 'JX'),
#  ('법률', 'NNG'),
#  ('이', 'JKS'),
#  ('정하', 'VV'),
#  ('는', 'ETM'),
#  ('바', 'NNB'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('재외국민', 'NNP'),
#  ('을', 'JKO'),
#  ('보호', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('의무', 'NNG'),
#  ('를', 'JKO'),
#  ('지', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('3', 'SN'),
#  ('조', 'NR'),
#  ('대한민국', 'NNP'),
#  ('의', 'JKG'),
#  ('영토', 'NNP'),
#  ('는', 'JX'),
#  ('한반도', 'NNP'),
#  ('와', 'JC'),
#  ('그', 'MM'),
#  ('부속', 'NNG'),
#  ('도서', 'NNP'),
#  ('로', 'JKB'),
#  ('하', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('4', 'SN'),
#  ('조', 'NR'),
#  ('대한민국', 'NNP'),
#  ('은', 'JX'),
#  ('통일', 'NNG'),
#  ('을', 'JKO'),
#  ('지향', 'NNG'),
#  ('하', 'XSV'),
#  ('며', 'EC'),
#  (',', 'SP'),
#  ('자유', 'NNG'),
#  ('민주', 'NNP'),
#  ('적', 'XSN'),
#  ('기본', 'NNG'),
#  ('질서', 'NNG'),
#  ('에', 'JKB'),
#  ('입각', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('평화', 'NNG'),
#  ('적', 'XSN'),
#  ('통일', 'NNG'),
#  ('정책', 'NNG'),
#  ('을', 'JKO'),
#  ('수립', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('이', 'NP'),
#  ('를', 'JKO'),
#  ('추진', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('5', 'SN'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('대한민국', 'NNP'),
#  ('은', 'JX'),
#  ('국제', 'NNG'),
#  ('평화', 'NNP'),
#  ('의', 'JKG'),
#  ('유지', 'NNG'),
#  ('에', 'JKB'),
#  ('노력', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('침략', 'NNG'),
#  ('적', 'XSN'),
#  ('전쟁', 'NNG'),
#  ('을', 'JKO'),
#  ('부인', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('국군', 'NNP'),
#  ('은', 'JX'),
#  ('국가', 'NNG'),
#  ('의', 'JKG'),
#  ('안전', 'NNG'),
#  ('보장', 'NNG'),
#  ('과', 'JC'),
#  ('국토방위', 'NNG'),
#  ('의', 'JKG'),
#  ('신성', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('의무', 'NNG'),
#  ('를', 'JKO'),
#  ('수행', 'NNG'),
#  ('하', 'XSV'),
#  ('ㅁ', 'ETN'),
#  ('을', 'JKO'),
#  ('사명', 'NNG'),
#  ('으로', 'JKB'),
#  ('하', 'VV'),
#  ('며', 'EC'),
#  (',', 'SP'),
#  ('그', 'MM'),
#  ('정치', 'NNG'),
#  ('적', 'XSN'),
#  ('중립', 'NNG'),
#  ('성', 'XSN'),
#  ('은', 'JX'),
#  ('준수', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('6', 'SN'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('헌법', 'NNG'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('체결', 'NNG'),
#  ('·', 'SP'),
#  ('공포', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('조약', 'NNG'),
#  ('과', 'JC'),
#  ('일반', 'NNG'),
#  ('적', 'XSN'),
#  ('으로', 'JKB'),
#  ('승인', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('국제', 'NNG'),
#  ('법규', 'NNG'),
#  ('는', 'JX'),
#  ('국내법', 'NNP'),
#  ('과', 'JC'),
#  ('같', 'VA'),
#  ('은', 'ETM'),
#  ('효력', 'NNG'),
#  ('을', 'JKO'),
#  ('가지', 'VV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('외국인', 'NNP'),
#  ('은', 'JX'),
#  ('국제법', 'NNP'),
#  ('과', 'JC'),
#  ('조약', 'NNG'),
#  ('이', 'JKS'),
#  ('정하', 'VV'),
#  ('는', 'ETM'),
#  ('바', 'NNB'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('그', 'MM'),
#  ('지위', 'NNG'),
#  ('가', 'JKS'),
#  ('보장', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('7', 'SN'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('공무원', 'NNG'),
#  ('은', 'JX'),
#  ('국민', 'NNG'),
#  ('전체', 'NNG'),
#  ('에', 'JKB'),
#  ('대하', 'VV'),
#  ('ㄴ', 'ETM'),
#  ('봉사자', 'NNG'),
#  ('이', 'VCP'),
#  ('며', 'EC'),
#  (',', 'SP'),
#  ('국민', 'NNG'),
#  ('에', 'JKB'),
#  ('대하', 'VV'),
#  ('아', 'EC'),
#  ('책임', 'NNG'),
#  ('을', 'JKO'),
#  ('지', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('공무원', 'NNP'),
#  ('의', 'JKG'),
#  ('신분', 'NNG'),
#  ('과', 'JC'),
#  ('정치', 'NNG'),
#  ('적', 'XSN'),
#  ('중립', 'NNG'),
#  ('성', 'XSN'),
#  ('은', 'JX'),
#  ('법률', 'NNG'),
#  ('이', 'JKS'),
#  ('정하', 'VV'),
#  ('는', 'ETM'),
#  ('바', 'NNB'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('보장', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('8', 'SN'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('정당', 'NNG'),
#  ('의', 'JKG'),
#  ('설립', 'NNG'),
#  ('은', 'JX'),
#  ('자유', 'NNG'),
#  ('이', 'VCP'),
#  ('며', 'EC'),
#  (',', 'SP'),
#  ('복수', 'NNP'),
#  ('정당', 'NNP'),
#  ('제', 'XSN'),
#  ('는', 'JX'),
#  ('보장', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('정당', 'NNP'),
#  ('은', 'JX'),
#  ('그', 'MM'),
#  ('목적', 'NNG'),
#  ('·', 'SP'),
#  ('조직', 'NNP'),
#  ('과', 'JC'),
#  ('활동', 'NNG'),
#  ('이', 'JKS'),
#  ('민주', 'NNG'),
#  ('적', 'XSN'),
#  ('이', 'VCP'),
#  ('어야', 'EC'),
#  ('하', 'VV'),
#  ('며', 'EC'),
#  (',', 'SP'),
#  ('국민', 'NNG'),
#  ('의', 'JKG'),
#  ('정치', 'NNG'),
#  ('적', 'XSN'),
#  ('의사', 'NNG'),
#  ('형성', 'NNG'),
#  ('에', 'JKB'),
#  ('참여', 'NNG'),
#  ('하', 'XSV'),
#  ('는데', 'EC'),
#  ('필요', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('조직', 'NNG'),
#  ('을', 'JKO'),
#  ('가지', 'VV'),
#  ('어야', 'EC'),
#  ('하', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('③', 'SW'),
#  ('정당', 'NNP'),
#  ('은', 'JX'),
#  ('법률', 'NNG'),
#  ('이', 'JKS'),
#  ('정하', 'VV'),
#  ('는', 'ETM'),
#  ('바', 'NNB'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('국가', 'NNG'),
#  ('의', 'JKG'),
#  ('보호', 'NNG'),
#  ('를', 'JKO'),
#  ('받', 'VV'),
#  ('으며', 'EC'),
#  (',', 'SP'),
#  ('국가', 'NNG'),
#  ('는', 'JX'),
#  ('법률', 'NNG'),
#  ('이', 'JKS'),
#  ('정하', 'VV'),
#  ('는', 'ETM'),
#  ('바', 'NNB'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('정당', 'NNG'),
#  ('운영', 'NNG'),
#  ('에', 'JKB'),
#  ('필요', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('자금', 'NNG'),
#  ('을', 'JKO'),
#  ('보조', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VX'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('④', 'SW'),
#  ('정당', 'NNP'),
#  ('의', 'JKG'),
#  ('목적', 'NNG'),
#  ('이나', 'JC'),
#  ('활동', 'NNG'),
#  ('이', 'JKS'),
#  ('민주', 'NNG'),
#  ('적', 'XSN'),
#  ('기본', 'NNG'),
#  ('질서', 'NNG'),
#  ('에', 'JKB'),
#  ('위배', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('때', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('정부', 'NNG'),
#  ('는', 'JX'),
#  ('헌법재판소', 'NNP'),
#  ('에', 'JKB'),
#  ('그', 'MM'),
#  ('해산', 'NNG'),
#  ('을', 'JKO'),
#  ('제소', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('있', 'VV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('정당', 'NNG'),
#  ('은', 'JX'),
#  ('헌법재판소', 'NNP'),
#  ('의', 'JKG'),
#  ('심판', 'NNG'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('해산', 'NNG'),
#  ('되', 'XSV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('9', 'SN'),
#  ('조', 'NR'),
#  ('국가', 'NNG'),
#  ('는', 'JX'),
#  ('전통문화', 'NNG'),
#  ('의', 'JKG'),
#  ('계승', 'NNP'),
#  ('·', 'SP'),
#  ('발전', 'NNP'),
#  ('과', 'JC'),
#  ('민족', 'NNG'),
#  ('문화', 'NNG'),
#  ('의', 'JKG'),
#  ('창달', 'NNG'),
#  ('에', 'JKB'),
#  ('노력', 'NNG'),
#  ('하', 'XSV'),
#  ('아야', 'EC'),
#  ('하', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('2', 'SN'),
#  ('장', 'NNP'),
#  ('국민의 권리와 의무', 'NNP'),
#  ('제', 'XPN'),
#  ('10', 'SN'),
#  ('조', 'NR'),
#  ('모든', 'MM'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('인간', 'NNG'),
#  ('으로서', 'JKB'),
#  ('의', 'JKG'),
#  ('존엄', 'NNG'),
#  ('과', 'JC'),
#  ('가치', 'NNG'),
#  ('를', 'JKO'),
#  ('가지', 'VV'),
#  ('며', 'EC'),
#  (',', 'SP'),
#  ('행복', 'NNG'),
#  ('을', 'JKO'),
#  ('추구', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('권리', 'NNG'),
#  ('를', 'JKO'),
#  ('가지', 'VV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('국가', 'NNG'),
#  ('는', 'JX'),
#  ('개인', 'NNG'),
#  ('이', 'JKS'),
#  ('가지', 'VV'),
#  ('는', 'ETM'),
#  ('불가침', 'NNG'),
#  ('의', 'JKG'),
#  ('기본', 'NNG'),
#  ('적', 'XSN'),
#  ('인권', 'NNG'),
#  ('을', 'JKO'),
#  ('확인', 'NNG'),
#  ('하', 'XSV'),
#  ('고', 'EC'),
#  ('이', 'NP'),
#  ('를', 'JKO'),
#  ('보장', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('의무', 'NNG'),
#  ('를', 'JKO'),
#  ('지', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('11', 'SN'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('모든', 'MM'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('법', 'NNG'),
#  ('앞', 'NNG'),
#  ('에', 'JKB'),
#  ('평등', 'NNG'),
#  ('하', 'XSV'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('누구', 'NP'),
#  ('이', 'VCP'),
#  ('든지', 'EC'),
#  ('성별', 'NNP'),
#  ('·', 'SP'),
#  ('종교', 'NNP'),
#  ('또는', 'MAJ'),
#  ('사회', 'NNG'),
#  ('적', 'XSN'),
#  ('신분', 'NNG'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('정치', 'NNG'),
#  ('적', 'XSN'),
#  ('·', 'SP'),
#  ('경제', 'NNG'),
#  ('적', 'XSN'),
#  ('·', 'SP'),
#  ('사회', 'NNG'),
#  ('적', 'XSN'),
#  ('·', 'SP'),
#  ('문화', 'NNG'),
#  ('적', 'XSN'),
#  ('생활', 'NNG'),
#  ('의', 'JKG'),
#  ('모든', 'MM'),
#  ('영역', 'NNG'),
#  ('에', 'JKB'),
#  ('있', 'VV'),
#  ('어서', 'EC'),
#  ('차별', 'NNG'),
#  ('을', 'JKO'),
#  ('받', 'VV'),
#  ('지', 'EC'),
#  ('아니하', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('사회', 'NNG'),
#  ('적', 'XSN'),
#  ('특수', 'NNP'),
#  ('계급', 'NNP'),
#  ('의', 'JKG'),
#  ('제도', 'NNG'),
#  ('는', 'JX'),
#  ('인정', 'NNG'),
#  ('되', 'XSV'),
#  ('지', 'EC'),
#  ('아니하', 'VX'),
#  ('며', 'EC'),
#  (',', 'SP'),
#  ('어떠', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('형태', 'NNG'),
#  ('로', 'JKB'),
#  ('도', 'JX'),
#  ('이', 'NP'),
#  ('를', 'JKO'),
#  ('창설', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄹ', 'ETM'),
#  ('수', 'NNB'),
#  ('없', 'VA'),
#  ('다', 'EF'),
#  ('.', 'SF'),
#  ('③', 'SW'),
#  ('훈장', 'NNP'),
#  ('등', 'NNB'),
#  ('의', 'JKG'),
#  ('영전', 'NNP'),
#  ('은', 'JX'),
#  ('이', 'NP'),
#  ('를', 'JKO'),
#  ('받', 'VV'),
#  ('은', 'ETM'),
#  ('자', 'NNB'),
#  ('에게', 'JKB'),
#  ('만', 'JX'),
#  ('효력', 'NNG'),
#  ('이', 'JKS'),
#  ('있', 'VV'),
#  ('고', 'EC'),
#  (',', 'SP'),
#  ('어떠', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('특권', 'NNP'),
#  ('도', 'JX'),
#  ('이', 'NP'),
#  ('에', 'JKB'),
#  ('따르', 'VV'),
#  ('지', 'EC'),
#  ('아니하', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('제', 'XPN'),
#  ('12', 'SN'),
#  ('조', 'NR'),
#  ('①', 'SW'),
#  ('모든', 'MM'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('신체의 자유', 'NNP'),
#  ('를', 'JKO'),
#  ('가지', 'VV'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('누구', 'NP'),
#  ('이', 'VCP'),
#  ('든지', 'EC'),
#  ('법률', 'NNG'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('지', 'EC'),
#  ('아니하', 'VX'),
#  ('고', 'EC'),
#  ('는', 'JX'),
#  ('체포', 'NNP'),
#  ('·', 'SP'),
#  ('구속', 'NNP'),
#  ('·', 'SP'),
#  ('압수', 'NNP'),
#  ('·', 'SP'),
#  ('수색', 'NNP'),
#  ('또는', 'MAJ'),
#  ('심문', 'NNP'),
#  ('을', 'JKO'),
#  ('받', 'VV'),
#  ('지', 'EC'),
#  ('아니하', 'VX'),
#  ('며', 'EC'),
#  (',', 'SP'),
#  ('법률', 'NNG'),
#  ('과', 'JC'),
#  ('적법', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('절차', 'NNG'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('지', 'EC'),
#  ('아니하', 'VX'),
#  ('고', 'EC'),
#  ('는', 'JX'),
#  ('처벌', 'NNP'),
#  ('·', 'SP'),
#  ('보안처분', 'NNP'),
#  ('또는', 'MAJ'),
#  ('강제', 'NNG'),
#  ('노역', 'NNG'),
#  ('을', 'JKO'),
#  ('받', 'VV'),
#  ('지', 'EC'),
#  ('아니하', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('②', 'SW'),
#  ('모든', 'MM'),
#  ('국민', 'NNG'),
#  ('은', 'JX'),
#  ('고문', 'NNG'),
#  ('을', 'JKO'),
#  ('받', 'VV'),
#  ('지', 'EC'),
#  ('아니하', 'VX'),
#  ('며', 'EC'),
#  (',', 'SP'),
#  ('형사', 'NNG'),
#  ('상', 'XSN'),
#  ('자기', 'NP'),
#  ('에게', 'JKB'),
#  ('불리', 'XR'),
#  ('하', 'XSA'),
#  ('ㄴ', 'ETM'),
#  ('진술', 'NNG'),
#  ('을', 'JKO'),
#  ('강요', 'NNG'),
#  ('당하', 'XSV'),
#  ('지', 'EC'),
#  ('아니하', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('③', 'SW'),
#  ('체포', 'NNP'),
#  ('·', 'SP'),
#  ('구속', 'NNP'),
#  ('·', 'SP'),
#  ('압수', 'NNP'),
#  ('또는', 'MAJ'),
#  ('수색', 'NNG'),
#  ('을', 'JKO'),
#  ('하', 'VV'),
#  ('ㄹ', 'ETM'),
#  ('때', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('적법', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('절차', 'NNG'),
#  ('에', 'JKB'),
#  ('따르', 'VV'),
#  ('아', 'EC'),
#  ('검사', 'NNG'),
#  ('의', 'JKG'),
#  ('신청', 'NNG'),
#  ('에', 'JKB'),
#  ('의하', 'VV'),
#  ('아', 'EC'),
#  ('법관', 'NNG'),
#  ('이', 'JKS'),
#  ('발부', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETM'),
#  ('영장', 'NNG'),
#  ('을', 'JKO'),
#  ('제시', 'NNG'),
#  ('하', 'XSV'),
#  ('아야', 'EC'),
#  ('하', 'VX'),
#  ('ㄴ다', 'EF'),
#  ('.', 'SF'),
#  ('다만', 'MAJ'),
#  (',', 'SP'),
#  ('현행범', 'NNP'),
#  ('인', 'NNG'),
#  ('이', 'VCP'),
#  ('ㄴ', 'ETM'),
#  ('경우', 'NNG'),
#  ('와', 'JC'),
#  ('장기', 'NNG'),
#  ('3', 'SN'),
#  ('년', 'NNB'),
#  ('이상', 'NNG'),
#  ('의', 'JKG'),
#  ('형', 'NNG'),
#  ('에', 'JKB'),
#  ('해당', 'NNG'),
#  ('하', 'XSV'),
#  ('는', 'ETM'),
#  ('죄', 'NNG'),
#  ('를', 'JKO'),
#  ('범하', 'VV'),
#  ('고', 'EC'),
#  ('도피', 'NNG'),
#  ('또는', 'MAJ'),
#  ('증거', 'NNG'),
#  ('인멸', 'NNG'),
#  ('의', 'JKG'),
#  ('염려', 'NNG'),
#  ('가', 'JKS'),
#  ('있', 'VV'),
#  ('을', 'ETM'),
#  ('때', 'NNG'),
#  ('에', 'JKB'),
#  ('는', 'JX'),
#  ('사후', 'NNG'),
#  ...]

# %% [markdown]
# - NNG → 일반 명사
# - NNP → 고유 명사
# - NNB → 의존 명사
# - JKS → 주격 조사
# - JKO → 목적격 조사
# - XSV → 동사 파생 접미사
# - EF  → 종결 어미

# %%
# <!-- JVMNotFoundException: No JVM shared library file (libjvm.so) found. Try setting up the JAVA_HOME environment variable properly. -->
# [문제해결]  
# - java 설치 
#   sudo apt update
#   sudo apt install openjdk-17-jdk -y
# - java 설치위치 확인
#   readlink -f $(which java)
#   => 예) /usr/lib/jvm/java-17-openjdk-amd64/bin/java
# - JAVA_HOME 설정
#   nano ~/.bashrc
#   - 아래 코드 추가하기(저장 ctrl + o, 종료 ctrl + x)
#     export JAVA_HOME=/usr/lib/jvm/java-17-openjdk-amd64
#     export PATH=$JAVA_HOME/bin:$PATH
# - 현재 shell에 적용하기
#   - source ~/.bashrc
# vs-code 종료하고, 다시 열기

# %%
print(type(nouns))
nouns[:10]
# Out:
# <class 'list'>
# ['대한민국', '헌법', '역사', '전통', '국민', '운동', '건립', '대한민국', '임시', '정부']

# %%
from collections import Counter

counter = Counter(nouns)

top5 = counter.most_common(5)

print(top5)
# Out:
# [('법률', 128), ('수', 90), ('대통령', 84), ('국가', 70), ('국회', 69)]

# %% [markdown]
# ## 문자열 타입으로 변환하기
# - 워드클라우드에 넣기 위해서는 문자열타입으로 변환

# %%
# 리스트 -> 문자열
text = ", ". join(nouns)
text[:10]
# Out:
# '대한민국, 헌법, '

# %% [markdown]
# ## 워드 클라우드 그리기

# %% [markdown]
# - TTF (TrueType Font) : 글꼴 파일
# - generate(text)는 문자열 text를 분석해서 워드클라우드 데이터를 생성하는 메서드이다.
# - 글자 크기 → 주로 단어 빈도 기반
# - 위치 → 빈 공간을 찾아 배치하므로 랜덤 요소 있음
# - 방향 → 설정에 따라 랜덤 요소 있음
# - 색상 → colormap 또는 color_func 기반, 기본은 랜덤 요소 있음
#
# - bilinear : 주변 픽셀 값을 참고해서 중간 색을 계산하므로, 이미지가 확대되거나 축소될 때 계단 현상이 덜하고 더 부드럽게 보인다.

# %%
my_path='./fonts/NanumGothic.ttf'
fig = plt.figure(figsize=(10,10))

# 워드 클라우드 객체 설정
wordcloud = WordCloud(font_path=my_path, 
                      background_color='white', 
                      width=1200, 
                      height=800).generate(text)
# 워드 클라우드 그리기
# plt.imshow(wordcloud)

# interpolation='bilinear' : 이미지를 화면에 표시할 때 픽셀 사이의 값을 보간하는 방법
# plt.imshow(wordcloud.to_array(), interpolation='bilinear')  # 가장 정확하고 안정적인 출력 방법
plt.imshow(wordcloud, interpolation='bilinear')   # WordCloud 객체는 __array__()라는 내부 메서드를 가지고 있어서 numpy array처럼 동작
plt.axis('off')   # 축 표시를 제거함
plt.show()

# %% [markdown]
# ## 이미지 모양으로 워드 클라우드 그리기

# %% [markdown]
# ### 마스킹 하기

# %% [markdown]
# ```
# R = Red
# G = Green
# B = Blue
# A = Alpha(투명도)
# ```

# %%
import numpy as np
from PIL import Image

icon = Image.open('korea_map.png').convert("RGBA")
# icon.putalpha(255)
mask = Image.new("RGB", icon.size, (255,255,255))  # 흰색
# mask = Image.new("RGB", icon.size, (0,0,0))  # 검정색 (0~255)
mask
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %% [markdown]
# ```
# mask.paste(
#     icon,           # 붙일 이미지
#     (0, 0),         # 붙일 위치
#     icon             # 투명도 마스크
# )
# ```

# %%
mask.paste(icon, icon)
mask
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
mask = np.array(mask)
mask.shape
# Out:
# (500, 500, 3)

# %% [markdown]
# ### 워드클라우드 그리기

# %%
from PIL import Image
icon = Image.open('./korea_map.png').convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon) 
mask = np.array(mask)
wordcloud = WordCloud(font_path=my_path,
                      # background_color=None,
                      background_color='white',
                      width=1200,
                      height=800,
                      mask= mask).generate(text)
fig = plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### 워드클라우드 그리기

# %%
from PIL import Image
icon = Image.open('./heart.png').convert("RGBA")
mask = Image.new("RGB", icon.size, (255,255,255))
mask.paste(icon,icon) 
#mask.paste(icon) 
mask = np.array(mask)
wordcloud = WordCloud(font_path=my_path,
                      background_color='lightgray',
                      width=1200,
                      height=800,
                      colormap='autumn',
                     mask= mask).generate(text)
fig = plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wordcloud.to_file("test.png")

# %% [markdown]
# # 다른 데이터로 해보기
# ## Korpora 데이터 활용
# - 공식문서 사용방법 :  https://ko-nlp.github.io/Korpora/ko-docs/introduction/installation.html
# - 데이터 문서 : https://github.com/ko-nlp/Korpora

# %% [markdown]
# - Korpora라는 한국어 말뭉치 관리 라이브러리에서 KorSTS 데이터셋을 다운로드하는 코드이다.
# - KorSTS는 Korean Semantic Textual Similarity 데이터셋이다. 즉 두 한국어 문장이 의미적으로 얼마나 비슷한지 점수로 표현한 데이터이다.

# %%
from wordcloud import WordCloud
from konlpy.tag import Komoran
import matplotlib.pyplot as plt
from konlpy.corpus import kolaw

# %% [markdown]
# ## 데이터 준비

# %%
# uv add Korpora

# %%
from Korpora import Korpora
Korpora.fetch("korsts")
# Out:
# [Korpora] Corpus `korsts` is already installed at /home/sang/Korpora/korsts/sts-train.tsv
# [Korpora] Corpus `korsts` is already installed at /home/sang/Korpora/korsts/sts-dev.tsv
# [Korpora] Corpus `korsts` is already installed at /home/sang/Korpora/korsts/sts-test.tsv

# %%
from Korpora import Korpora
corpus = Korpora.load("korsts")
# Out:
#     Korpora 는 다른 분들이 연구 목적으로 공유해주신 말뭉치들을
#     손쉽게 다운로드, 사용할 수 있는 기능만을 제공합니다.
#
#     말뭉치들을 공유해 주신 분들에게 감사드리며, 각 말뭉치 별 설명과 라이센스를 공유 드립니다.
#     해당 말뭉치에 대해 자세히 알고 싶으신 분은 아래의 description 을 참고,
#     해당 말뭉치를 연구/상용의 목적으로 이용하실 때에는 아래의 라이센스를 참고해 주시기 바랍니다.
#
#     # Description
#     Author : KakaoBrain
#     Repository : https://github.com/kakaobrain/KorNLUDatasets
#     References :
#         - Ham, J., Choe, Y. J., Park, K., Choi, I., & Soh, H. (2020). KorNLI and KorSTS: New Benchmark
#            Datasets for Korean Natural Language Understanding. arXiv preprint arXiv:2004.03289.
#            (https://arxiv.org/abs/2004.03289)
#
#     This is the dataset repository for our paper
#     "KorNLI and KorSTS: New Benchmark Datasets for Korean Natural Language Understanding."
#     (https://arxiv.org/abs/2004.03289)
#     We introduce KorNLI and KorSTS, which are NLI and STS datasets in Korean.
#
#     # License
#     Creative Commons Attribution-ShareAlike license (CC BY-SA 4.0)
#     Details in https://creativecommons.org/licenses/by-sa/4.0/
#
# [Korpora] Corpus `korsts` is already installed at /home/sang/Korpora/korsts/sts-train.tsv
# [Korpora] Corpus `korsts` is already installed at /home/sang/Korpora/korsts/sts-dev.tsv
# [Korpora] Corpus `korsts` is already installed at /home/sang/Korpora/korsts/sts-test.tsv

# %% [markdown]
# ## 형태소 추출

# %%
# 말뭉치의 텍스트 부분만 추출
train_texts = corpus.train
# dev_texts = corpus.dev
# test_texts = corpus.
train_texts = train_texts.texts

# 말뭉치를 텍스트로 만들기
text_corpus = " ".join(train_texts)
print(type(text_corpus))
text_corpus[:200]
# Out:
# <class 'str'>
# '비행기가 이륙하고 있다. 한 남자가 큰 플루트를 연주하고 있다. 한 남자가 피자에 치즈를 뿌려놓고 있다. 세 남자가 체스를 하고 있다. 한 남자가 첼로를 연주하고 있다. 몇몇 남자들이 싸우고 있다. 남자가 담배를 피우고 있다. 남자가 피아노를 치고 있다. 한 남자가 기타를 치고 노래를 부르고 있다. 사람이 고양이를 천장에 던지고 있다. 그 남자는 다른 남자'

# %%
# 형태소 추출: 시간이 좀 걸림(5분정도)
tagger = Komoran()
nouns = tagger.nouns(text_corpus)

# %% [markdown]
# ## 문자열로 만들기

# %%
# 추출한 형태로소를 ,로 구분하기
text2 = ", ". join(nouns)
text2[:20]
# Out:
# '비행기, 이륙, 남자, 플루트, 연주'

# %% [markdown]
# ## 워드클라우드 그리기

# %%
# 클라우딩 객체 설정
my_path='./fonts/NanumGothic.ttf'
wordcloud = WordCloud(font_path=my_path, 
                      background_color='white', 
                      width=1200, 
                      height=800).generate(text2)
fig = plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1199.5), np.float64(799.5), np.float64(-0.5))
